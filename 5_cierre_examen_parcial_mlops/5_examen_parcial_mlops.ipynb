# %% [markdown]
# # PASO 5 — Cierre examen parcial MLOps (IA08)
#
# **Examen Parcial 3 · UNI**
#
# 1. Tablero central de experimentos (PASO 0→4 + sprint7 HPO)
# 2. Checklist examen final IA08 + plantilla informe 9 secciones
# 3. Análisis gap/overfitting (calibración train 280 vs eval 400 vs holdout 120)
# 4. Guía demo 10–12 min
# 5. Auditoría global entregable 0→4
#
# Ejecutar primero: `run_cierre_examen.py` y `run_auditoria_paso5.py`.

# %%
from pathlib import Path
import subprocess
import sys

ROOT = Path(".").resolve()
for script in ("run_cierre_examen.py", "run_auditoria_paso5.py"):
    result = subprocess.run([sys.executable, str(ROOT / script)], cwd=ROOT, capture_output=True, text=True)
    print(result.stdout)
    if result.returncode != 0:
        print(result.stderr)
        raise SystemExit(result.returncode)
# Out:
# PASO 5: tablero=13 filas checklist=100.0% auditoria=OK
# Auditoría PASO 5: pasada1=OK pasada2=✅

# %%
import json
from pathlib import Path

import pandas as pd

ROOT = Path(".").resolve()
tab = pd.read_csv(ROOT / "1_tablero_experimentos_consolidado.csv")
chk = pd.read_csv(ROOT / "2_checklist_examen_final_ia08.csv")
gap = json.loads((ROOT / "3_informe_gap_overfitting_calibracion.json").read_text(encoding="utf-8"))
audit = json.loads((ROOT / "5_informe_auditoria_global_entregable_0_4.json").read_text(encoding="utf-8"))
resumen = json.loads((ROOT / "8_informe_resumen_paso5.json").read_text(encoding="utf-8"))

display(tab)
pct = (chk["estado"] == "CUMPLIDO").mean() * 100
print(f"Checklist: {pct:.1f}% cumplido ({(chk['estado']=='CUMPLIDO').sum()}/{len(chk)})")
display(chk[chk["estado"] != "CUMPLIDO"])
print("Gap eval vs holdout:", json.dumps(gap["gap_metricas_eval_vs_holdout"], indent=2))
print("Auditoría global:", audit["veredicto"])
print(json.dumps(resumen, indent=2))
# Out:
#                          exp_id paso          variante  alcance_n  F1_macro  \
# 0                paso0_etl_n400    0               ETL        400       NaN
# 1            paso1_rag_pgvector    1               RAG        400       NaN
# 2       paso2_criticidad_capa_a    2      PolicyEngine        400       NaN
# 3                paso3_baseline    3          Baseline        400    0.3623
# 4                    paso3_var1    3              Var1        400    0.3353
# 5                    paso3_var2    3              Var2        400    0.4353
# 6     paso3_baseline_holdout120    3  Baseline_holdout        120    0.3709
# 7         paso3_var1_holdout120    3      Var1_holdout        120    0.3095
# 8         paso3_var2_holdout120    3      Var2_holdout        120    0.4691
# 9           sprint7_hpo_trial68  HPO     Bayes_trial68        600    0.7012
# 10  paso4_cal_baseline_isotonic    4          Baseline        400       NaN
# 11      paso4_cal_var1_isotonic    4              Var1        400       NaN
# 12      paso4_cal_var2_isotonic    4              Var2        400       NaN
#
#     F1_stop     ECE      EC  FNR_stop  override_rate       fecha  \
# 0       NaN     NaN     NaN       NaN            NaN  2026-06-12
# 1       NaN     NaN     NaN       NaN            NaN  2026-06-12
# 2       NaN     NaN     NaN       NaN            NaN  2026-06-12
# 3    0.3008  0.4477  0.1105    0.3333            NaN  2026-06-12
# 4    0.0571  0.4400  0.1467    0.9667            NaN  2026-06-12
# 5    0.3908  0.4193  0.1231    0.4333          0.165  2026-06-12
# 6    0.3256  0.4500  0.1050    0.2222            NaN  2026-06-12
# 7    0.0000  0.4167  0.1550    1.0000            NaN  2026-06-12
# 8    0.5000  0.4250  0.1125    0.2222            NaN  2026-06-12
# 9    0.8148     NaN  0.1290       NaN            NaN  2026-06-06
# 10      NaN  0.0032     NaN       NaN            NaN  2026-06-12
# 11      NaN  0.0350     NaN       NaN            NaN  2026-06-12
# 12      NaN  0.0261     NaN       NaN            NaN  2026-06-12
#
#                                      notas_honestidad
# 0   Corpus 88008; train 280 / holdout 120 / eval 4...
# 1   history_eval_hash_overlap=0; pgvector entregab...
# 2          Gate A/B simulado; params sprint7 trial 68
# 3   DeepSeek 246 API + 154 cache; sin RAG ni middl...
# 4   40 CrewAI cache (D5) + 360 abstención pausa (C...
# 5   Middleware Gate B; 66 overrides (16.5%); 0 API...
# 6            Hold-out 30% estratificado (120 tickets)
# 7            Hold-out 30% estratificado (120 tickets)
# 8            Hold-out 30% estratificado (120 tickets)
# 9   HPO sin LLM; CV 5-fold n=600 calibración; test...
# 10  Calibración post-hoc isotónica fit train 280; ...
# 11  Calibración post-hoc isotónica fit train 280; ...
# 12  Calibración post-hoc isotónica fit train 280; ...
# Checklist: 100.0% cumplido (27/27)
# Empty DataFrame
# Columns: [id, requisito, seccion_informe, artefacto_evidencia, estado, notas]
# Index: []
# Gap eval vs holdout: [
#   {
#     "variante": "Baseline",
#     "F1_stop_eval_n400": 0.3008,
#     "F1_stop_holdout120": 0.3256,
#     "delta_F1_stop_holdout_minus_eval": 0.0248,
#     "FNR_stop_eval": 0.3333,
#     "FNR_stop_holdout": 0.2222,
#     "interpretacion": "Gap eval/holdout acotado (<5pp F1-stop)"
#   },
#   {
#     "variante": "Var1",
#     "F1_stop_eval_n400": 0.0571,
#     "F1_stop_holdout120": 0.0,
#     "delta_F1_stop_holdout_minus_eval": -0.0571,
#     "FNR_stop_eval": 0.9667,
#     "FNR_stop_holdout": 1.0,
#     "interpretacion": "FNR-stop extremo por abstenci\u00f3n D5 \u2014 no overfitting sino dise\u00f1o Chow"
#   },
#   {
#     "variante": "Var2",
#     "F1_stop_eval_n400": 0.3908,
#     "F1_stop_holdout120": 0.5,
#     "delta_F1_stop_holdout_minus_eval": 0.1092,
#     "FNR_stop_eval": 0.4333,
#     "FNR_stop_holdout": 0.2222,
#     "interpretacion": "Holdout F1-stop superior (+0.109) \u2014 generalizaci\u00f3n favorable"
#   }
# ]
# Auditoría global: OK
# {
#   "paso": 5,
#   "ia08": true,
#   "timestamp": "2026-06-12T23:23:22.630525+00:00",
#   "n_experimentos_tablero": 13,
#   "checklist_cumplimiento_pct": 100.0,
#   "checklist_cumplidos": 27,
#   "checklist_total": 27,
#   "auditoria_global_veredicto": "OK",
#   "gaps_auditoria": [],
#   "gap_overfitting_resumen": [
#     "Var1 FNR-stop 97% en n=400 vs 100% holdout \u2014 colapso consistente fuera piloto",
#     "Var2 F1-stop holdout (0.50) > eval (0.39) \u2014 no hay overfitting cl\u00e1sico en Var2",
#     "ECE isot\u00f3nica holdout > n400 en Var1/Var2 \u2014 calibrador puede sobreajustar train 280"
#   ],
#   "honesty_notes": [
#     "Var1 = 10% CrewAI real (piloto D5) + 90% abstenci\u00f3n pausa (Chow 1970) \u2014 dise\u00f1o intencional.",
#     "No escalar CrewAI a n=400: costo API y evidencia desfavorable en piloto; Var2 = contribuci\u00f3n principal.",
#     "HITL costo USD = supuesto documentado (5/20/3 min, $45/h), no medido en campo.",
#     "Proxy Bugzilla severity \u2192 play/pausa/stop \u2260 FMEA operacional completo.",
#     "Calibraci\u00f3n isot\u00f3nica fit train 280; eval reportada n=400 + holdout 120 \u2014 gap documentado."
#   ],
#   "veredicto": "PASO 5 completado \u2014 entregable listo examen parcial"
# }

# %% [markdown]
# ## Veredicto
#
# Ver `6_veredicto_final_entregable.md` y `4_guia_demo_presentacion_10min.md`.
